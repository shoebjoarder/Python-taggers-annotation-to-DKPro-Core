# %%
# Import libraries
from flair.data import Sentence
from flair.models import SequenceTagger
from cassis import *

# %% [markdown]
# ## Import cas and typesystem
#
# These two files are generated from the Dkpro using OpenNLPSegmenter
#
# flair ver. 0.5
#
# dkpro-cassis ver. 0.2.9

# %%
tsfile = 'TypeSystem.xml'
csfile = 'OpenNlpSegmenter.xmi'

TOKEN_TYPE = "de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token"
SENTENCE_TYPE = "de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Sentence"

# Load Typesystem
with open(tsfile, 'rb') as f:
    typesystem = load_typesystem(f)

# Load Cas
with open(csfile, 'rb') as f:
    cas = load_cas_from_xmi(f, typesystem=typesystem)

# %%
tokens = list(cas.select(TOKEN_TYPE))
words = [cas.get_covered_text(token) for token in tokens]
tokens[:3]
# Out:
# /home/allan/00_env/env/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecatedWarning: get_covered_text is deprecated. Use annotation.get_covered_text()
# [de_tudarmstadt_ukp_dkpro_core_api_segmentation_type_Token(xmiID=12, parent=None, lemma=None, stem=None, pos=None, morph=None, id=None, form=None, syntacticFunction=None, begin=0, end=5, type='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token'),
#  de_tudarmstadt_ukp_dkpro_core_api_segmentation_type_Token(xmiID=13, parent=None, lemma=None, stem=None, pos=None, morph=None, id=None, form=None, syntacticFunction=None, begin=6, end=9, type='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token'),
#  de_tudarmstadt_ukp_dkpro_core_api_segmentation_type_Token(xmiID=14, parent=None, lemma=None, stem=None, pos=None, morph=None, id=None, form=None, syntacticFunction=None, begin=10, end=14, type='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token')]

# %%
print(cas.sofa_string)
# Out:
# Obama was born in Honolulu, Hawaii, making him the first president not born in North America .
# After graduating from Columbia University in 1983, he worked as a community organizer in Chicago .
# In 1988, he enrolled in Harvard Law School, where he was the first black person to head the Harvard Law Review .
# After graduating, he became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004 .
# Turning to elective politics, he represented the 13th district from 1997 until 2004 in the Illinois Senate, when he ran for the U.S. Senate. Obama received national attention in 2004 with his March Senate primary win, his well-received July Democratic National Convention keynote address, and his landslide November election to the Senate .
# In 2008, he was nominated for president a year after his presidential campaign began, and after close primary campaigns against Hillary Clinton .
# Obama was elected over Republican John McCain and was inaugurated alongside Joe Biden on January 20, 2009 .
# Nine months later, he was named the 2009 Nobel Peace Prize laureate .

# %% [markdown]
# ## Implementation of FlairNLP Named Entity Recognition on the sofa_string generated from the cas

# %%
cas = Cas(typesystem=load_dkpro_core_typesystem())

for t in cas.typesystem.get_types():
    print(t)
# Out:
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.morph.Morpheme', supertypeName='uima.tcas.Annotation', description=None, _children={}, _features={'morphTag': Feature(name='morphTag', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Div', supertypeName='uima.tcas.Annotation', description='Document structure element.', _children={'de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Document': Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Document', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Div', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'divType': Feature(name='divType', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'id': Feature(name='id', rangeTypeName='uima.cas.String', description='If this unit had an ID in the source format from which it was imported, it may be\n                        stored here. IDs are typically not assigned by DKPro Core components. If an ID is present, it\n                        should be respected by writers.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Heading': Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Heading', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Div', description='Document title, section heading, etc.', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'divType': Feature(name='divType', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'id': Feature(name='id', rangeTypeName='uima.cas.String', description='If this unit had an ID in the source format from which it was imported, it may be\n                        stored here. IDs are typically not assigned by DKPro Core components. If an ID is present, it\n                        should be respected by writers.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Paragraph': Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Paragraph', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Div', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'divType': Feature(name='divType', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'id': Feature(name='id', rangeTypeName='uima.cas.String', description='If this unit had an ID in the source format from which it was imported, it may be\n                        stored here. IDs are typically not assigned by DKPro Core components.  ...
# Type(name='de.tudarmstadt.ukp.dkpro.core.mallet.type.WordEmbedding', supertypeName='uima.tcas.Annotation', description='An array representing the word embedding vector.', _children={}, _features={'WordEmbedding': Feature(name='WordEmbedding', rangeTypeName='uima.cas.FloatArray', description='A word embedding vector.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.type.ReadabilityScore', supertypeName='uima.tcas.Annotation', description=None, _children={}, _features={'measureName': Feature(name='measureName', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'score': Feature(name='score', rangeTypeName='uima.cas.Double', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.LexicalPhrase', supertypeName='uima.tcas.Annotation', description=None, _children={}, _features={'text': Feature(name='text', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.phonetics.type.PhoneticTranscription', supertypeName='uima.tcas.Annotation', description='<p>Represents the phonetic transcription of some textual element (usually a Token).\n                Phonetic transcriptions are e.g. generated by transcription processes like Soundex or Metaphone.</p>', _children={}, _features={'transcription': Feature(name='transcription', rangeTypeName='uima.cas.String', description='The actual transcription', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'name': Feature(name='name', rangeTypeName='uima.cas.String', description='The name of the transcription process that was used', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.Constituent', supertypeName='uima.tcas.Annotation', description=None, _children={'de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.QP': Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.QP', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.Constituent', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'constituentType': Feature(name='constituentType', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'parent': Feature(name='parent', rangeTypeName='uima.tcas.Annotation', description='The parent constituent', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'children': Feature(name='children', rangeTypeName='uima.cas.FSArray', description=None, elementType='uima.tcas.Annotation', multipleReferencesAllowed=None, _has_reserved_name=False), 'syntacticFunction': Feature(name='syntacticFunction', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.ADVP': Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.ADVP', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.Constituent', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'constituentType': Feature(name='constituentType', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'parent': Feature(name='parent', rangeTypeName='uima.tcas.Annotation', description='The parent constituent', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'children': Feature(name='children', rangeTypeName='uima.cas.FSArray', description=None, elementType='uima.tcas.Annotation', multipleReferencesAllowed=None, _has_reserved_name=False), 'syntacticFunction': Feature(name='syntacticFunction', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.PRP': Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.PRP', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.constituent.Constituent', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'constituentType': Feature(name='constituentType', rangeTypeName='uima.cas.String', des ...
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.morph.MorphologicalFeatures', supertypeName='uima.tcas.Annotation', description='Morphological categories that can be attached to tokens.\n\n                The features are supposed to match the Universal Dependency v1 features.', _children={}, _features={'gender': Feature(name='gender', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'number': Feature(name='number', rangeTypeName='uima.cas.String', description='Singular/plural', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'case': Feature(name='case', rangeTypeName='uima.cas.String', description='Nouns: nominative, genetiv, dative, ...', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'degree': Feature(name='degree', rangeTypeName='uima.cas.String', description='Adjectives: comparative/Superlative', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'verbForm': Feature(name='verbForm', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'tense': Feature(name='tense', rangeTypeName='uima.cas.String', description='Verbs: past tense, present tense, future tense, etc.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'mood': Feature(name='mood', rangeTypeName='uima.cas.String', description='Verbs: indicative, imperative, subjunctive', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'voice': Feature(name='voice', rangeTypeName='uima.cas.String', description='Verbs: active/passive', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'definiteness': Feature(name='definiteness', rangeTypeName='uima.cas.String', description='Definite or indefinite', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'value': Feature(name='value', rangeTypeName='uima.cas.String', description='The original morphological analysis results as produced by a tool or as recorded in a\n                        corpus (if available). If the categories were originally encoded in such a string, the other\n                        features are filled by analyzing this string. If the categories were provided separately, e.g.\n                        by different attributed in an XML-encoded corpus, this field may remain empty.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'person': Feature(name='person', rangeTypeName='uima.cas.String', description='Verbs: 1st, 2nd, 3rd person', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'aspect': Feature(name='aspect', rangeTypeName='uima.cas.String', description='Verbs: perfective, imperfective', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'animacy': Feature(name='animacy', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'negative': Feature(name='negative', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'numType': Feature(name='numType', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'possessive': Feature(name='possessive', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'pronType': Feature(name='pronType', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'reflex': Feature(name='reflex', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'transitivity': Feature(name='transitivity', rangeTypeName='uima.cas.Stri ...
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.metadata.type.MetaDataStringField', supertypeName='uima.tcas.Annotation', description='<p>A general purpose annotation to store document-wide information in the form of\n                arbitrary key-value string pairs.</p>', _children={}, _features={'key': Feature(name='key', rangeTypeName='uima.cas.String', description='Name of a metadata field.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'value': Feature(name='value', rangeTypeName='uima.cas.String', description='The field value.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.semantics.type.SemanticPredicate', supertypeName='uima.tcas.Annotation', description='One of the predicates of a sentence (often a main verb, but nouns and adjectives can also be\n                predicates). The SemanticPredicate annotation can be attached to predicates in a sentence.\n                Semantic predicates express events or situations and take semantic arguments\n                expressing the participants in these events ore situations. All forms of main verbs\n                can be annotated with a SemanticPredicate. However, there are also many nouns and\n                adjectives that take arguments and can thus be annotated with a SemanticPredicate,\n                e.g. event nouns, such as "suggestion" (with arguments what and by whom), or\n                relational adjectives, such as "proud" (with arguments who and of what).\n\n                @deprecated use SemPred instead', _children={}, _features={'category': Feature(name='category', rangeTypeName='uima.cas.String', description='A more detailed specification of the predicate type depending on the theory being used,\n                        e.g. a frame name.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'arguments': Feature(name='arguments', rangeTypeName='uima.cas.FSArray', description="The predicate's arguments.", elementType='de.tudarmstadt.ukp.dkpro.core.api.semantics.type.SemanticArgument', multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='org.dkpro.core.io.nift.metadata.ArticleMetaData', supertypeName='uima.cas.AnnotationBase', description='A document annotation that describes the metadata of a\n                newspaper article.', _children={}, _features={'guid': Feature(name='guid', rangeTypeName='uima.cas.Integer', description='The GUID field specifies a (4-byte) integer that is\n                        guaranteed\n                        to be unique for every document\n                        in the corpus.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'alternateUrl': Feature(name='alternateUrl', rangeTypeName='uima.cas.String', description='This field specifies the location on nytimes.com of\n                        the article. When present, this URL is preferred to the URL field\n                        on articles published on or after April 02,\n                        2006, as the linked\n                        page will have richer content.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'url': Feature(name='url', rangeTypeName='uima.cas.String', description="This field specifies the location on nytimes.com of\n                        the article. The 'Alternative Url'\n                        field is preferred to this field\n                        on articles published on or after\n                        April 02, 2006, as the\n                        linked page\n                        will have richer content.", elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'publicationDate': Feature(name='publicationDate', rangeTypeName='uima.cas.String', description="This field specifies the date of the article's\n                        publication. This field is specified in the\n                        format\n                        YYYYMMDD'T'HHMMSS where:\n                        1. YYYY is the four-digit year.\n                        2. MM is\n                        the two-digit month [01-12].\n                        3. DD is the two-digit day [01-31].\n                        4.\n                        T is a constant value.\n                        5. HH is the two-digit hour [00-23].\n                        6. MM is\n                        the two-digit minute-past-the hour [00-59]\n                        7. SS is the two-digit\n                        seconds-past-the-minute [00-59].\n                        Please note that values for HH,MM,\n                        and SS are not defined for this\n                        corpus, that is to day\n                        HH,MM, and SS\n                        are always defined to be '00'.", elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'typesOfMaterial': Feature(name='typesOfMaterial', rangeTypeName='uima.cas.StringArray', description='This field specifies a normalized list of terms\n                        describing the general editorial category of the article.\n                        These\n                        tags are algorithmically assigned and\n                        manually verified by\n                        nytimes.com production staff.\n                        Examples Include:\n                        * REVIEW\n                        * OBITUARY\n                        * ANALYSIS', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'headline': Feature(name='headline', rangeTypeName='uima.cas.String', description='This field specifies the headline of the article as it\n                        appeared in the\n                        print edition of the New York\n                        Times.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'onlineHeadline': Feature(name='onlineHeadline', rangeTypeName='uima.cas.String', description='This field specifies the headline displayed with the\n                        article on\n                        nytimes.com. Often\n            ...
# Type(name='de.tudarmstadt.ukp.dkpro.core.io.jwpl.type.ArticleInfo', supertypeName='uima.tcas.Annotation', description='Contains basic information about the article.', _children={}, _features={'Authors': Feature(name='Authors', rangeTypeName='uima.cas.Integer', description='Number of unique authors of this article', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'Revisions': Feature(name='Revisions', rangeTypeName='uima.cas.Integer', description='Number of revisions of this article.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'FirstAppearance': Feature(name='FirstAppearance', rangeTypeName='uima.cas.Long', description='The Timestamp of the first appearance of this article.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'LastAppearance': Feature(name='LastAppearance', rangeTypeName='uima.cas.Long', description='The Timestamp of the last appearance of this article.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.semantics.type.SemanticField', supertypeName='uima.tcas.Annotation', description='The SemanticField is a coarse-grained semantic category that can be attached to\n                nouns, verbs or adjectives. Semantic field information is present e.g. in WordNet as\n                lexicographer file names. Previously, this kind of semantic information has also\n                been called supersenses or semantic types.', _children={}, _features={'value': Feature(name='value', rangeTypeName='uima.cas.String', description='The value or name of the semantic field. Examples of semantic field values are:\n                        location, artifact, event, communication, attribute', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.transform.type.SofaChangeAnnotation', supertypeName='uima.tcas.Annotation', description='Encodes an edit operation that can be interpreted by the ApplyChangesAnnotator.', _children={}, _features={'value': Feature(name='value', rangeTypeName='uima.cas.String', description='In case of an "insert" or "replace" operation, this feature indicates the value to be\n                        inserted or replaced.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'operation': Feature(name='operation', rangeTypeName='uima.cas.String', description='Operation to perform: "insert", "replace", "delete"', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'reason': Feature(name='reason', rangeTypeName='uima.cas.String', description='The reason for the change.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='org.dkpro.core.api.xml.type.XmlNode', supertypeName='uima.tcas.Annotation', description='Supertype for XmlElements and XmlTextNodes.', _children={'org.dkpro.core.api.xml.type.XmlElement': Type(name='org.dkpro.core.api.xml.type.XmlElement', supertypeName='org.dkpro.core.api.xml.type.XmlNode', description='XML element', _children={}, _features={'uri': Feature(name='uri', rangeTypeName='uima.cas.String', description='Namespace URI of the element.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'localName': Feature(name='localName', rangeTypeName='uima.cas.String', description='Local name of the XML element.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'attributes': Feature(name='attributes', rangeTypeName='uima.cas.FSArray', description='Array of attributes of the XML element.', elementType='org.dkpro.core.api.xml.type.XmlAttribute', multipleReferencesAllowed=None, _has_reserved_name=False), 'children': Feature(name='children', rangeTypeName='uima.cas.FSArray', description='Children of this XML element.', elementType='org.dkpro.core.api.xml.type.XmlNode', multipleReferencesAllowed=None, _has_reserved_name=False), 'qName': Feature(name='qName', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'parent': Feature(name='parent', rangeTypeName='org.dkpro.core.api.xml.type.XmlElement', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'org.dkpro.core.api.xml.type.XmlTextNode': Type(name='org.dkpro.core.api.xml.type.XmlTextNode', supertypeName='org.dkpro.core.api.xml.type.XmlNode', description='XML text node.', _children={}, _features={'text': Feature(name='text', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'captured': Feature(name='captured', rangeTypeName='uima.cas.Boolean', description='Whether the text node has been added to the document text.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'parent': Feature(name='parent', rangeTypeName='org.dkpro.core.api.xml.type.XmlElement', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})}, _features={'parent': Feature(name='parent', rangeTypeName='org.dkpro.core.api.xml.type.XmlElement', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.metadata.type.TagDescription', supertypeName='uima.cas.TOP', description='Description of an individual tag.', _children={}, _features={'name': Feature(name='name', rangeTypeName='uima.cas.String', description='The name of the tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Stem', supertypeName='uima.tcas.Annotation', description=None, _children={}, _features={'value': Feature(name='value', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity', supertypeName='uima.tcas.Annotation', description='Named entities refer e.g. to persons, locations, organizations and so on. They often consist of\n                multiple tokens.', _children={'de.tudarmstadt.ukp.dkpro.core.api.ner.type.PerDesc': Type(name='de.tudarmstadt.ukp.dkpro.core.api.ner.type.PerDesc', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'value': Feature(name='value', rangeTypeName='uima.cas.String', description='The class/category of the named entity, e.g. person, location, etc.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'identifier': Feature(name='identifier', rangeTypeName='uima.cas.String', description='Identifier of the named entity, e.g. a reference into a person database.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.ner.type.Language': Type(name='de.tudarmstadt.ukp.dkpro.core.api.ner.type.Language', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'value': Feature(name='value', rangeTypeName='uima.cas.String', description='The class/category of the named entity, e.g. person, location, etc.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'identifier': Feature(name='identifier', rangeTypeName='uima.cas.String', description='Identifier of the named entity, e.g. a reference into a person database.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.ner.type.Organization': Type(name='de.tudarmstadt.ukp.dkpro.core.api.ner.type.Organization', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'value': Feature(name='value', rangeTypeName='uima.cas.String', description='The class/category of the named entity, e.g. person, location, etc.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'identifier': Feature(name='identifier', rangeTypeName='uima.cas.String', description='Identifier of the named entity, e.g. a reference into a person database.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.ner.type.Norp': Type(name='de.tudarmstadt.ukp.dkpro.core.api.ner.type.Norp', supertypeName='de.tudarmstadt.ukp.d ...
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.semantics.type.SemArgLink', supertypeName='uima.cas.TOP', description='The SemArgLink type is used to attach SemPred annotations to their respective SemArg\n                annotations while giving each link a role.', _children={}, _features={'role': Feature(name='role', rangeTypeName='uima.cas.String', description='The role which the argument takes. The value depends on the theory being used, e.g.\n                        Arg0, Arg1, etc. or Buyer, Seller, etc.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'target': Feature(name='target', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.semantics.type.SemArg', description='The target argument.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.TokenForm', supertypeName='uima.tcas.Annotation', description='A alternative token text which should be used instead of the covered text if set on a token.', _children={}, _features={'value': Feature(name='value', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.semantics.type.SemArg', supertypeName='uima.tcas.Annotation', description='The SemArg annotation is attached to semantic arguments of semantic\n                predicates. Semantic arguments are characterized by their semantic role, e.g. Agent,\n                Experiencer, Topic. The semantic role of an argument is related to its semantic type\n                (for communication verbs, the Agent can be a person or an organization, but\n                typically not food).', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.PennTree', supertypeName='uima.tcas.Annotation', description='<p>The Penn Treebank-style phrase structure string.</p>', _children={}, _features={'PennTree': Feature(name='PennTree', rangeTypeName='uima.cas.String', description='Contains a Penn Treebank-style representation of a tree.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'TransformationNames': Feature(name='TransformationNames', rangeTypeName='uima.cas.String', description='The name(s) of the transformation(s) that have been performed on the PennTree', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.structure.type.Field', supertypeName='uima.tcas.Annotation', description=None, _children={}, _features={'name': Feature(name='name', rangeTypeName='uima.cas.String', description='the name of the tag', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Split', supertypeName='uima.tcas.Annotation', description='This type represents a part of a decompounding word. A Split can be either a CompoundPart or a\n                LinkingMorpheme.', _children={'de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.CompoundPart': Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.CompoundPart', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Split', description='<p>A CompoundPart represents one fragment from the compounding word. Besides that, it can\n                store other CompoundParts if it can be split again. The way it stores a decompounding word represents a\n                decompounding tree.</p>', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'splits': Feature(name='splits', rangeTypeName='uima.cas.FSArray', description='Sub-splits of the current split.', elementType='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Split', multipleReferencesAllowed=None, _has_reserved_name=False)}), 'de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.LinkingMorpheme': Type(name='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.LinkingMorpheme', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Split', description='This type represents a linking morpheme between two CompoundParts.', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'splits': Feature(name='splits', rangeTypeName='uima.cas.FSArray', description='Sub-splits of the current split.', elementType='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Split', multipleReferencesAllowed=None, _has_reserved_name=False)})}, _features={'splits': Feature(name='splits', rangeTypeName='uima.cas.FSArray', description='Sub-splits of the current split.', elementType='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Split', multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.frequency.tfidf.type.Tfidf', supertypeName='uima.tcas.Annotation', description='Annotates the tf.idf score of a token, stem, or lemma.', _children={}, _features={'tfidfValue': Feature(name='tfidfValue', rangeTypeName='uima.cas.Double', description='The tf.idf score.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'term': Feature(name='term', rangeTypeName='uima.cas.String', description='The string that was used to compute this tf.idf score.\n                        If a stem or lemma was used, the covered text of this annotation does not need to be equal to\n                        this string.\n\n                        This string can be used to construct a vector space with the right terms without having to\n                        access the indexes again.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.coref.type.CoreferenceChain', supertypeName='uima.cas.AnnotationBase', description='Marks the beginning of a chain.', _children={}, _features={'first': Feature(name='first', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.coref.type.CoreferenceLink', description='This is the first corefernce link in coreference chain', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# ...
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.dependency.ADVCL', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.dependency.Dependency', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'Governor': Feature(name='Governor', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token', description='The governor word', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'Dependent': Feature(name='Dependent', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token', description='The dependent word', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'DependencyType': Feature(name='DependencyType', rangeTypeName='uima.cas.String', description='The dependency type', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'flavor': Feature(name='flavor', rangeTypeName='uima.cas.String', description='Flavor of the dependency relation (basic, collapsed, enhanced, etc...)', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.dependency.AUX0', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.dependency.Dependency', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'Governor': Feature(name='Governor', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token', description='The governor word', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'Dependent': Feature(name='Dependent', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token', description='The dependent word', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'DependencyType': Feature(name='DependencyType', rangeTypeName='uima.cas.String', description='The dependency type', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'flavor': Feature(name='flavor', rangeTypeName='uima.cas.String', description='Flavor of the dependency relation (basic, collapsed, enhanced, etc...)', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.dependency.PUNCT', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.syntax.type.dependency.Dependency', description=None, _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'Governor': Feature(name='Governor', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token', description='The governor word', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'Dependent': Feature(name='Dependent', rangeTypeName='de.tudarmstadt.ukp.dkpro.core.api.segmentation.type.Token', description='The dependent word', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'DependencyType': Feature(name='DependencyType', rangeTypeName='uima.cas.String', description='The dependency type', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'flavor': Feature(name='flavor', rangeTypeName='uima.cas.String', description='Flavor of the dependency relation (basic, collapsed, enhanced, etc...)', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_EMO', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_X', description='emoticon', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_URL', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_X', description='URL or email address', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_HASH', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_X', description='Hashtag (indicates topic/category for tweet)', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_NPV', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_NOUN', description='proper noun + verbal', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_DM', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_X', description='discourse marker, indications of continuation of a message across multiple tweets', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_INT', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_X', description='proper noun + verbal', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_NNV', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_NOUN', description='nominal + verbal', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.tweet.POS_AT', supertypeName='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_X', description='at-mention (indicates another user as a recipient of a tweet)', _children={}, _features={}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'PosValue': Feature(name='PosValue', rangeTypeName='uima.cas.String', description='Fine-grained POS tag. This is the tag as produced by a POS tagger or obtained from a\n                        reader.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'coarseValue': Feature(name='coarseValue', rangeTypeName='uima.cas.String', description='Coarse-grained POS tag. This may be produced by a POS tagger or reader in addition to\n                        the fine-grained tag.', elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})
# Type(name='uima.tcas.DocumentAnnotation', supertypeName='uima.tcas.Annotation', description=None, _children={}, _features={'language': Feature(name='language', rangeTypeName='uima.cas.String', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)}, _inherited_features={'begin': Feature(name='begin', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'end': Feature(name='end', rangeTypeName='uima.cas.Integer', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False), 'sofa': Feature(name='sofa', rangeTypeName='uima.cas.Sofa', description=None, elementType=None, multipleReferencesAllowed=None, _has_reserved_name=False)})

# %%
document = "Obama was born in Honolulu, Hawaii, making him the first president not born in North America . After graduating from Columbia University in 1983, he worked as a community organizer in Chicago . In 1988, he enrolled in Harvard Law School, where he was the first black person to head the Harvard Law Review . After graduating, he became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004 . Turning to elective politics, he represented the 13th district from 1997 until 2004 in the Illinois Senate, when he ran for the U.S. Senate. Obama received national attention in 2004 with his March Senate primary win, his well-received July Democratic National Convention keynote address, and his landslide November election to the Senate . In 2008, he was nominated for president a year after his presidential campaign began, and after close primary campaigns against Hillary Clinton . Obama was elected over Republican John McCain and was inaugurated alongside Joe Biden on January 20, 2009 . Nine months later, he was named the 2009 Nobel Peace Prize laureate ."

# %%
model_name = 'ner'
sentence = Sentence(document)

nlp = SequenceTagger.load(model_name)
nlp.predict(sentence)
# Out:
# 2020-06-27 14:31:05,344 loading file /home/allan/.flair/models/en-ner-conll03-v0.4.pt
# [Sentence: "Obama was born in Honolulu, Hawaii, making him the first president not born in North America . After graduating from Columbia University in 1983, he worked as a community organizer in Chicago . In 1988, he enrolled in Harvard Law School, where he was the first black person to head the Harvard Law Review . After graduating, he became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004 . Turning to elective politics, he represented the 13th district from 1997 until 2004 in the Illinois Senate, when he ran for the U.S. Senate. Obama received national attention in 2004 with his March Senate primary win, his well-received July Democratic National Convention keynote address, and his landslide November election to the Senate . In 2008, he was nominated for president a year after his presidential campaign began, and after close primary campaigns against Hillary Clinton . Obama was elected over Republican John McCain and was inaugurated alongside Joe Biden on January 20, 2009 . Nine months later, he was named the 2009 Nobel Peace Prize laureate ."   [− Tokens: 188  − Token-Labels: "Obama <S-PER> was born in Honolulu, <B-LOC> Hawaii, <E-LOC> making him the first president not born in North <B-LOC> America <E-LOC> . After graduating from Columbia <B-ORG> University <E-ORG> in 1983, he worked as a community organizer in Chicago <S-LOC> . In 1988, he enrolled in Harvard <B-LOC> Law <I-LOC> School, <E-LOC> where he was the first black person to head the Harvard <B-ORG> Law <I-ORG> Review <E-ORG> . After graduating, he became a civil rights attorney and an academic, teaching constitutional law at the University <B-ORG> of <I-ORG> Chicago <I-ORG> Law <I-ORG> School <E-ORG> from 1992 to 2004 . Turning to elective politics, he represented the 13th district from 1997 until 2004 in the Illinois <B-LOC> Senate, <E-LOC> when he ran for the U.S. <S-LOC> Senate. Obama <S-PER> received national attention in 2004 with his March Senate <S-ORG> primary win, his well-received July Democratic <B-MISC> National <I-MISC> Convention <E-MISC> keynote address, and his landslide November election to the Senate <S-ORG> . In 2008, he was nominated for president a year after his presidential campaign began, and after close primary campaigns against Hillary <B-PER> Clinton <E-PER> . Obama <S-PER> was elected over Republican <S-MISC> John <B-PER> McCain <E-PER> and was inaugurated alongside Joe <B-PER> Biden <E-PER> on January 20, 2009 . Nine months later, he was named the 2009 Nobel <B-MISC> Peace <I-MISC> Prize <E-MISC> laureate ."]]

# %%
print('The following NER tags are found:')

for entity in sentence.get_spans('ner'):
    print(entity)
# Out:
# The following NER tags are found:
# Span [1]: "Obama"   [− Labels: PER (0.9999)]
# Span [5,6]: "Honolulu, Hawaii,"   [− Labels: LOC (0.9625)]
# Span [15,16]: "North America"   [− Labels: LOC (0.9967)]
# Span [21,22]: "Columbia University"   [− Labels: ORG (0.9744)]
# Span [32]: "Chicago"   [− Labels: LOC (1.0)]
# Span [39,40,41]: "Harvard Law School,"   [− Labels: LOC (0.8482)]
# Span [52,53,54]: "Harvard Law Review"   [− Labels: ORG (0.8027)]
# Span [72,73,74,75,76]: "University of Chicago Law School"   [− Labels: ORG (0.8778)]
# Span [97,98]: "Illinois Senate,"   [− Labels: LOC (0.6585)]
# Span [104]: "U.S."   [− Labels: LOC (0.9955)]
# Span [106]: "Obama"   [− Labels: PER (0.9999)]
# Span [115]: "Senate"   [− Labels: ORG (1.0)]
# Span [121,122,123]: "Democratic National Convention"   [− Labels: MISC (0.8813)]
# Span [133]: "Senate"   [− Labels: ORG (1.0)]
# Span [155,156]: "Hillary Clinton"   [− Labels: PER (0.9616)]
# Span [158]: "Obama"   [− Labels: PER (0.9999)]
# Span [162]: "Republican"   [− Labels: MISC (1.0)]
# Span [163,164]: "John McCain"   [− Labels: PER (0.9906)]
# Span [169,170]: "Joe Biden"   [− Labels: PER (0.9988)]
# Span [184,185,186]: "Nobel Peace Prize"   [− Labels: MISC (0.9971)]

# %%
# Get annotation type
NERType = cas.typesystem.get_type("de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity")
#AnnotationType = cas.typesystem.get_type(NERType)

# %%
i = 0
for span in sentence.get_spans('ner'):
    if span.tag == 'PER':
        val = 'person'
    if span.tag == 'LOC':
        val = 'location'
    if span.tag == 'ORG':
        val = "organization"
    if span.tag == 'MISC':
        val = "miscellaneous"
    ner_annotation = NERType(begin = span.start_pos,
                             end = span.end_pos,
                             value = val)
    cas.add_annotation(ner_annotation)
    i=i+1
xmi = cas.to_xmi('./flairNLP.xmi', pretty_print=True)

# %%
csfile = 'flairNLP.xmi'
# Load Cas
with open(csfile, 'rb') as f:
    cas = load_cas_from_xmi(f, typesystem=typesystem)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b23232262cec> in <module>
#       2 # Load Cas
#       3 with open(csfile, 'rb') as f:
# ----> 4     cas = load_cas_from_xmi(f, typesystem=cas)
#
# ~/00_env/env/lib/python3.6/site-packages/cassis/xmi.py in load_cas_from_xmi(source, typesystem)
#      38         return deserializer.deserialize(BytesIO(source.encode("utf-8")), typesystem=typesystem)
#      39     else:
# ---> 40         return deserializer.deserialize(source, typesystem=typesystem)
#      41
#      42
#
# ~/00_env/env/lib/python3.6/site-packages/cassis/xmi.py in deserialize(self, source, typesystem)
#     110                         # We saw the closing tag of a new feature
#     111                         state = OUTSIDE_FS
# --> 112                         fs = self._parse_feature_structure(typesystem, elem, children)
#     113                         feature_structures[fs.xmiID] = fs
#     114
#
# ~/00_env/env/lib/python3.6/site-packages/cassis/xmi.py in _parse_feature_structure(self, typesystem, elem, children)
#     225         typename = elem.tag[9:].replace("/", ".").replace("ecore}", "").strip()
#     226
# --> 227         AnnotationType = typesystem.get_type(typename)
#     228         attributes = dict(elem.attrib)
#     229         attributes.update(children)
#
# AttributeError: 'Cas' object has no attribute 'get_type'

# %%
tokens = list(cas.select("de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity"))
words = [cas.get_covered_text(token) for token in tokens]
tokens[:4]
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecatedWarning: get_covered_text is deprecated. Use annotation.get_covered_text()
# [de_tudarmstadt_ukp_dkpro_core_api_ner_type_NamedEntity(xmiID=217, value='person', identifier=None, begin=0, end=5, type='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity'),
#  de_tudarmstadt_ukp_dkpro_core_api_ner_type_NamedEntity(xmiID=219, value='location', identifier=None, begin=18, end=35, type='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity'),
#  de_tudarmstadt_ukp_dkpro_core_api_ner_type_NamedEntity(xmiID=221, value='location', identifier=None, begin=79, end=92, type='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity'),
#  de_tudarmstadt_ukp_dkpro_core_api_ner_type_NamedEntity(xmiID=223, value='organization', identifier=None, begin=117, end=136, type='de.tudarmstadt.ukp.dkpro.core.api.ner.type.NamedEntity')]

# %% [markdown]
# ## Import the new cas
#
# This file is generated from the DKPro-Cassis which has FlairNLP NER annotations

# %%
csfile = 'OpenNlpPosTagger.xmi'
PosTagger = "de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS"

# Load Cas
with open(csfile, 'rb') as f:
    cas = load_cas_from_xmi(f, typesystem=typesystem)

# %%
tokens = list(cas.select(PosTagger))
words = [cas.get_covered_text(token) for token in tokens]
tokens[:4]
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecatedWarning: get_covered_text is deprecated. Use annotation.get_covered_text()
# [de_tudarmstadt_ukp_dkpro_core_api_lexmorph_type_pos_POS_ADP(xmiID=527, begin=15, end=17, PosValue='IN', coarseValue='ADP', type='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_ADP'),
#  de_tudarmstadt_ukp_dkpro_core_api_lexmorph_type_pos_POS_ADP(xmiID=540, begin=76, end=78, PosValue='IN', coarseValue='ADP', type='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_ADP'),
#  de_tudarmstadt_ukp_dkpro_core_api_lexmorph_type_pos_POS_ADP(xmiID=545, begin=95, end=100, PosValue='IN', coarseValue='ADP', type='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_ADP'),
#  de_tudarmstadt_ukp_dkpro_core_api_lexmorph_type_pos_POS_ADP(xmiID=547, begin=112, end=116, PosValue='IN', coarseValue='ADP', type='de.tudarmstadt.ukp.dkpro.core.api.lexmorph.type.pos.POS_ADP')]
